# %% [markdown]
# Source: [Medium](https://medium.com/geekculture/how-to-create-and-plot-a-swiss-roll-using-sklearn-cbd2c81fddc6) / [His Notebook](https://colab.research.google.com/drive/104uFkXq3Lv3ggj_WnGy9NUb1R52Xg9C-?usp=sharing#scrollTo=zMGLMx5BirdZ)

# %%
from sklearn.datasets import make_swiss_roll
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.style.use('classic')

# %% [markdown]
# # Draw the roll

# %%
X, y = make_swiss_roll(n_samples=50000, random_state=42)

# %%
figure_size = 33
fig = plt.figure(figsize=(figure_size,figure_size))
ax = fig.add_subplot(222, projection='3d')
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.nipy_spectral)
plt.show()

# %% [markdown]
# # Apply manifold learning
