# %%
import matplotlib.pyplot as plt
import numpy as np

import bz2
import _pickle

# %%
plt.rcParams['figure.figsize'] = [20, 8]
plt.rcParams.update({'font.size': 18})
pickle_data_path = 'data/SVD-Meaningful_PCs/faces.pkl.pbz2'

# %%
def decompress_pickle(file):
    data = bz2.BZ2File(file, 'rb')
    data = _pickle.load(data)
    return data.to_numpy()

# %%
training_faces = decompress_pickle(pickle_data_path)
m = 168
n = 192
# person 1 has 64 pictures, person 2 has 62 pictures etc.
n_faces = [64, 62, 64, 64, 62, 64, 64, 64, 64, 64, 60, 59, 60, 63, 62, 63, 63,
           64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64,
           64, 64]

# %%
fig1 = plt.figure()


col = training_faces.T[0]
ax = fig1.add_subplot(161)
np_avg_face = np.reshape(col, (m, n)).T
img_avg = ax.imshow(np_avg_face)
img_avg.set_cmap('gray')
plt.axis('off')


col = training_faces.T[85]
ax = fig1.add_subplot(162)
np_avg_face = np.reshape(col, (m, n)).T
img_avg = ax.imshow(np_avg_face)
img_avg.set_cmap('gray')
plt.axis('off')


col = training_faces.T[184]
ax = fig1.add_subplot(163)
np_avg_face = np.reshape(col, (m, n)).T
img_avg = ax.imshow(np_avg_face)
img_avg.set_cmap('gray')
plt.axis('off')


col = training_faces.T[520]
ax = fig1.add_subplot(164)
np_avg_face = np.reshape(col, (m, n)).T
img_avg = ax.imshow(np_avg_face)
img_avg.set_cmap('gray')
plt.axis('off')


col = training_faces.T[751]
ax = fig1.add_subplot(165)
np_avg_face = np.reshape(col, (m, n)).T
img_avg = ax.imshow(np_avg_face)
img_avg.set_cmap('gray')
plt.axis('off')


col = training_faces.T[1245]
ax = fig1.add_subplot(166)
np_avg_face = np.reshape(col, (m, n)).T
img_avg = ax.imshow(np_avg_face)
img_avg.set_cmap('gray')
plt.axis('off')


plt.show()
